# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
connection_string = "postgres:glory@localhost:5432/gun_violence_db"
engine = create_engine(f'postgresql://{connection_string}')

# %%
overdoses = "overdoses.csv"
overdoses_df = pd.read_csv(overdoses)


columns = ["State","Population","Deaths"]
transformed_o = overdoses_df[columns].copy()
transformed_o.reset_index(inplace=True)

transformed_o= transformed_o.rename(columns={"index":"id",
                                                    "State": "state",
                                                    "Population":"population",
                                                    "Deaths":"deaths"})

transformed_o["population"]=transformed_o["population"].str.replace(",","")
transformed_o["deaths"]=transformed_o["deaths"].str.replace(",","")
transformed_o

transformed_o.set_index("id", inplace=True)
transformed_o.to_sql(name='overdoses', con=engine, if_exists='append', index=True)

# states = list(transformed_o["state"].unique())
# states

# states = pd.DataFrame(states)
# states = states.rename(columns={0:"state"})
# states.to_sql(name='states', con=engine, if_exists='append', index=True)

# %%
accidental_deaths = "accidental deaths.csv"
accidental_deaths_df = pd.read_csv(accidental_deaths)
# accidental_deaths_df.drop(accidental_deaths_df[accidental_deaths_df.State == 'South Carolina'])
accidental_deaths_df.drop(accidental_deaths_df['State'].index)
# dataframe.drop(dataframe[dataframe['column'] operator value].index)
accidental_deaths_df.head()
# Out:
#    Incident ID  Incident Date           State    City Or County  \
# 0      2371338  July 26, 2022  South Carolina      Johns Island
# 1      2370647  July 26, 2022         Indiana            Muncie
# 2      2370544  July 25, 2022      Washington        Ellensburg
# 3      2369189  July 24, 2022        Michigan             Niles
# 4      2366931  July 22, 2022         Florida  Saint Petersburg
#
#                     Address  # Killed  # Injured  Operations
# 0                  Jules St         1          0         NaN
# 1         2810 S. Monroe St         1          0         NaN
# 2                    Yew St         1          0         NaN
# 3  3100 block of Detroit Rd         1          0         NaN
# 4       5800 Lynn Lake Dr S         1          0         NaN

# %%
# Create a filtered dataframe from specific columns
columns = ["Incident ID", "Incident Date", "State", "City Or County", "# Injured", "# Killed"]
transformed= accidental_deaths_df[columns].copy()
transformed.reset_index(inplace=True)

# Rename the column headers
transformed = transformed.rename(columns={"index":"id",
                                                    "Incident ID": "incident_id",
                                                    "Incident Date": "incident_date",
                                                    "State": "state",
                                                    "City Or County": "city_county",
                                                    "# Injured":"no_injured",
                                                    "# Killed": "no_killed"})

transformed.set_index("id", inplace=True)

transformed.head()

transformed.to_sql(name='accidental_deaths', con=engine, if_exists='append', index=True)
# Out:
# ---------------------------------------------------------------------------
# ForeignKeyViolation                       Traceback (most recent call last)
# c:\Users\jeyae\anaconda3\envs\bootcamp\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1788                     self.dialect.do_executemany(
# -> 1789                         cursor, statement, parameters, context
#    1790                     )
#
# c:\Users\jeyae\anaconda3\envs\bootcamp\lib\site-packages\sqlalchemy\dialects\postgresql\psycopg2.py in do_executemany(self, cursor, statement, parameters, context)
#     956                 fetch=bool(context.compiled.returning),
# --> 957                 **kwargs
#     958             )
#
# c:\Users\jeyae\anaconda3\envs\bootcamp\lib\site-packages\psycopg2\extras.py in execute_values(cur, sql, argslist, template, page_size, fetch)
#    1269         parts[-1:] = post
# -> 1270         cur.execute(b''.join(parts))
#    1271         if fetch:
#
# ForeignKeyViolation: insert or update on table "accidental_deaths" violates foreign key constraint "accidental_deaths_state_fkey"
# DETAIL:  Key (state)=(District of Columbia) is not present in table "overdoses".
#
#
# The above exception was the direct cause of the following exception:
#
# IntegrityError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_436\322524110.py in <module>
#      17 transformed.head()
#      18
# ---> 19 transformed.to_sql(name='accidental_deaths', con=engine, if_exists='append', index=True)
#
# c:\Users\jeyae\anaconda3\envs\bootcamp\lib\site-packages\pandas\core\generic.py in to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2880             chunksize=chunksize,
#    2881             dtype=dtype,
# -> 2882             method=method,
#    2883         )
#    2884
#
# c:\Users\jeyae\anaconda3\envs\bootcamp\lib\site-packages\pandas\io\sql.py in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method, engine, **engine_kwargs)
#     726         method=method,
#     727         engine=engine,
# --> 728         **engine_kwargs,
#     729     )
#     730
#
# c:\Users\jeyae\anaconda3\envs\bootcamp\lib\site-packages\pandas\io\sql.py in to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method, engine, **engine_kwargs)
#    1768             chunksize=chunksize,
#    1769             method=method,
# -> 1770             **engine_kwargs,
#    1771         )
#    1772
#
# c:\Users\jeyae\anaconda3\envs\bootcamp\lib\site-packages\pandas\io\sql.py in insert_records(self, table, con, frame, name, index, schema, chunksize, method, **engine_kwargs)
#    1348                 raise ValueError("inf cannot be used with MySQL") from err
#    1349             else:
# -> 1350                 raise err
#    1351
#    1352
#
# c:\Users\jeyae\anaconda3\envs\bootcamp\lib\site-packages\pandas\io\sql.py in insert_records(self, table, con, frame, name, index, schema, chunksize, method, **engine_kwargs)
#    1338
#    1339         try:
# -> 1340             table.insert(chunksize=chunksize, method=method)
#    1341         except exc.SQLAlchemyError as err:
#    1342             # GH34431
#
# c:\Users\jeyae\anaconda3\envs\bootcamp\lib\site-packages\pandas\io\sql.py in insert(self, chunksize, method)
#     965
#     966                 chunk_iter = zip(*[arr[start_i:end_i] for arr in data_list])
# --> 967                 exec_insert(conn, keys, chunk_iter)
#     968
#     969     def _query_iterator(
#
# c:\Users\jeyae\anaconda3\envs\bootcamp\lib\site-packages\pandas\io\sql.py in _execute_insert(self, conn, keys, data_iter)
#     880         """
#     881         data = [dict(zip(keys, row)) for row in data_iter]
# --> 882         conn.execute(self.table.insert(), data)
#     883
#     884     def _execute_insert_multi(self, conn, keys: list[str], data_iter):
#
# c:\Users\jeyae\anaconda3\envs\bootcamp\lib\site-packages\sqlalchemy\engine\base.py in execute(self, statement, *multiparams, **params)
#    1293             )
#    1294         else:
# -> 1295             return meth(self, multiparams, params, _EMPTY_EXECUTION_OPTS)
#    1296
#    1297     def _execute_function(self, func, multiparams, params, execution_options):
#
# c:\Users\jeyae\anaconda3\envs\bootcamp\lib\site-packages\sqlalchemy\sql\elements.py in _execute_on_connection(self, connection, multiparams, params, execution_options, _force)
#     324         if _force or self.supports_execution:
#     325             return connection._execute_clauseelement(
# --> 326                 self, multiparams, params, execution_options
#     327             )
#     328         else:
#
# c:\Users\jeyae\anaconda3\envs\bootcamp\lib\site-packages\sqlalchemy\engine\base.py in _execute_clauseelement(self, elem, multiparams, params, execution_options)
#    1495             elem,
#    1496             extracted_params,
# -> 1497             cache_hit=cache_hit,
#    1498         )
#    1499         if has_events:
#
# c:\Users\jeyae\anaconda3\envs\bootcamp\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1850         except BaseException as e:
#    1851             self._handle_dbapi_exception(
# -> 1852                 e, statement, parameters, cursor, context
#    1853             )
#    1854
#
# c:\Users\jeyae\anaconda3\envs\bootcamp\lib\site-packages\sqlalchemy\engine\base.py in _handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    2031             elif should_wrap:
#    2032                 util.raise_(
# -> 2033                     sqlalchemy_exception, with_traceback=exc_info[2], from_=e
#    2034                 )
#    2035             else:
#
# c:\Users\jeyae\anaconda3\envs\bootcamp\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     205
#     206         try:
# --> 207             raise exception
#     208         finally:
#     209             # credit to
#
# c:\Users\jeyae\anaconda3\envs\bootcamp\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1787                 if not evt_handled:
#    1788                     self.dialect.do_executemany(
# -> 1789                         cursor, statement, parameters, context
#    1790                     )
#    1791             elif not parameters and context.no_parameters:
#
# c:\Users\jeyae\anaconda3\envs\bootcamp\lib\site-packages\sqlalchemy\dialects\postgresql\psycopg2.py in do_executemany(self, cursor, statement, parameters, context)
#     955                 template=executemany_values,
#     956                 fetch=bool(context.compiled.returning),
# --> 957                 **kwargs
#     958             )
#     959
#
# c:\Users\jeyae\anaconda3\envs\bootcamp\lib\site-packages\psycopg2\extras.py in execute_values(cur, sql, argslist, template, page_size, fetch)
#    1268             parts.append(b',')
#    1269         parts[-1:] = post
# -> 1270         cur.execute(b''.join(parts))
#    1271         if fetch:
#    1272             result.extend(cur.fetchall())
#
# IntegrityError: (psycopg2.errors.ForeignKeyViolation) insert or update on table "accidental_deaths" violates foreign key constraint "accidental_deaths_state_fkey"
# DETAIL:  Key (state)=(District of Columbia) is not present in table "overdoses".
#
# [SQL: INSERT INTO accidental_deaths (id, incident_id, incident_date, state, city_county, no_injured, no_killed) VALUES (%(id)s, %(incident_id)s, %(incident_date)s, %(state)s, %(city_county)s, %(no_injured)s, %(no_killed)s)]
# [parameters: ({'id': 0, 'incident_id': 2371338, 'incident_date': 'July 26, 2022', 'state': 'South Carolina', 'city_county': 'Johns Island', 'no_injured': 0, 'no_killed': 1}, {'id': 1, 'incident_id': 2370647, 'incident_date': 'July 26, 2022', 'state': 'Indiana', 'city_county': 'Muncie', 'no_injured': 0, 'no_killed': 1}, {'id': 2, 'incident_id': 2370544, 'incident_date': 'July 25, 2022', 'state': 'Washington', 'city_county': 'Ellensburg', 'no_injured': 0, 'no_killed': 1}, {'id': 3, 'incident_id': 2369189, 'incident_date': 'July 24, 2022', 'state': 'Michigan', 'city_county': 'Niles', 'no_injured': 0, 'no_killed': 1}, {'id': 4, 'incident_id': 2366931, 'incident_date': 'July 22, 2022', 'state': 'Florida', 'city_county': 'Saint Petersburg', 'no_injured': 0, 'no_killed': 1}, {'id': 5, 'incident_id': 2366254, 'incident_date': 'July 21, 2022', 'state': 'South Carolina', 'city_county': 'North Charleston', 'no_injured': 0, 'no_killed': 1}, {'id': 6, 'incident_id': 2364234, 'incident_date': 'July 19, 2022', 'state': 'Michigan', 'city_county': 'Detroit', 'no_injured': 0, 'no_killed': 1}, {'id': 7, 'incident_id': 2363850, 'incident_date': 'July 19, 2022', 'state': 'Missouri', 'city_county': 'Rogersville', 'no_injured': 0, 'no_killed': 1}  ... displaying 10 of 2000 total bound parameter sets ...  {'id': 1998, 'incident_id': 1140927, 'incident_date': 'June 13, 2018', 'state': 'Wisconsin', 'city_county': 'Madison', 'no_injured': 0, 'no_killed': 1}, {'id': 1999, 'incident_id': 1141547, 'incident_date': 'June 13, 2018', 'state': 'South Dakota', 'city_county': 'Keystone', 'no_injured': 0, 'no_killed': 1})]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)

# %%
# Confirm tables
engine.table_names()
# Out:
# c:\Users\jeyae\anaconda3\envs\bootcamp\lib\site-packages\ipykernel_launcher.py:2: SADeprecationWarning: The Engine.table_names() method is deprecated and will be removed in a future release.  Please refer to Inspector.get_table_names(). (deprecated since: 1.4)
# ['overdoses',
#  'mass_shootings',
#  'accidental_deaths',
#  'accidental_injuries',
#  'states']

# %%
# Out:
# ---------------------------------------------------------------------------
# ForeignKeyViolation                       Traceback (most recent call last)
# c:\Users\jeyae\anaconda3\envs\bootcamp\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1788                     self.dialect.do_executemany(
# -> 1789                         cursor, statement, parameters, context
#    1790                     )
#
# c:\Users\jeyae\anaconda3\envs\bootcamp\lib\site-packages\sqlalchemy\dialects\postgresql\psycopg2.py in do_executemany(self, cursor, statement, parameters, context)
#     956                 fetch=bool(context.compiled.returning),
# --> 957                 **kwargs
#     958             )
#
# c:\Users\jeyae\anaconda3\envs\bootcamp\lib\site-packages\psycopg2\extras.py in execute_values(cur, sql, argslist, template, page_size, fetch)
#    1269         parts[-1:] = post
# -> 1270         cur.execute(b''.join(parts))
#    1271         if fetch:
#
# ForeignKeyViolation: insert or update on table "accidental_deaths" violates foreign key constraint "accidental_deaths_state_fkey"
# DETAIL:  Key (state)=(District of Columbia) is not present in table "overdoses".
#
#
# The above exception was the direct cause of the following exception:
#
# IntegrityError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_436\269198310.py in <module>
# ----> 1 transformed.to_sql(name='accidental_deaths', con=engine, if_exists='append', index=True)
#
# c:\Users\jeyae\anaconda3\envs\bootcamp\lib\site-packages\pandas\core\generic.py in to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2880             chunksize=chunksize,
#    2881             dtype=dtype,
# -> 2882             method=method,
#    2883         )
#    2884
#
# c:\Users\jeyae\anaconda3\envs\bootcamp\lib\site-packages\pandas\io\sql.py in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method, engine, **engine_kwargs)
#     726         method=method,
#     727         engine=engine,
# --> 728         **engine_kwargs,
#     729     )
#     730
#
# c:\Users\jeyae\anaconda3\envs\bootcamp\lib\site-packages\pandas\io\sql.py in to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method, engine, **engine_kwargs)
#    1768             chunksize=chunksize,
#    1769             method=method,
# -> 1770             **engine_kwargs,
#    1771         )
#    1772
#
# c:\Users\jeyae\anaconda3\envs\bootcamp\lib\site-packages\pandas\io\sql.py in insert_records(self, table, con, frame, name, index, schema, chunksize, method, **engine_kwargs)
#    1348                 raise ValueError("inf cannot be used with MySQL") from err
#    1349             else:
# -> 1350                 raise err
#    1351
#    1352
#
# c:\Users\jeyae\anaconda3\envs\bootcamp\lib\site-packages\pandas\io\sql.py in insert_records(self, table, con, frame, name, index, schema, chunksize, method, **engine_kwargs)
#    1338
#    1339         try:
# -> 1340             table.insert(chunksize=chunksize, method=method)
#    1341         except exc.SQLAlchemyError as err:
#    1342             # GH34431
#
# c:\Users\jeyae\anaconda3\envs\bootcamp\lib\site-packages\pandas\io\sql.py in insert(self, chunksize, method)
#     965
#     966                 chunk_iter = zip(*[arr[start_i:end_i] for arr in data_list])
# --> 967                 exec_insert(conn, keys, chunk_iter)
#     968
#     969     def _query_iterator(
#
# c:\Users\jeyae\anaconda3\envs\bootcamp\lib\site-packages\pandas\io\sql.py in _execute_insert(self, conn, keys, data_iter)
#     880         """
#     881         data = [dict(zip(keys, row)) for row in data_iter]
# --> 882         conn.execute(self.table.insert(), data)
#     883
#     884     def _execute_insert_multi(self, conn, keys: list[str], data_iter):
#
# c:\Users\jeyae\anaconda3\envs\bootcamp\lib\site-packages\sqlalchemy\engine\base.py in execute(self, statement, *multiparams, **params)
#    1293             )
#    1294         else:
# -> 1295             return meth(self, multiparams, params, _EMPTY_EXECUTION_OPTS)
#    1296
#    1297     def _execute_function(self, func, multiparams, params, execution_options):
#
# c:\Users\jeyae\anaconda3\envs\bootcamp\lib\site-packages\sqlalchemy\sql\elements.py in _execute_on_connection(self, connection, multiparams, params, execution_options, _force)
#     324         if _force or self.supports_execution:
#     325             return connection._execute_clauseelement(
# --> 326                 self, multiparams, params, execution_options
#     327             )
#     328         else:
#
# c:\Users\jeyae\anaconda3\envs\bootcamp\lib\site-packages\sqlalchemy\engine\base.py in _execute_clauseelement(self, elem, multiparams, params, execution_options)
#    1495             elem,
#    1496             extracted_params,
# -> 1497             cache_hit=cache_hit,
#    1498         )
#    1499         if has_events:
#
# c:\Users\jeyae\anaconda3\envs\bootcamp\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1850         except BaseException as e:
#    1851             self._handle_dbapi_exception(
# -> 1852                 e, statement, parameters, cursor, context
#    1853             )
#    1854
#
# c:\Users\jeyae\anaconda3\envs\bootcamp\lib\site-packages\sqlalchemy\engine\base.py in _handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    2031             elif should_wrap:
#    2032                 util.raise_(
# -> 2033                     sqlalchemy_exception, with_traceback=exc_info[2], from_=e
#    2034                 )
#    2035             else:
#
# c:\Users\jeyae\anaconda3\envs\bootcamp\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     205
#     206         try:
# --> 207             raise exception
#     208         finally:
#     209             # credit to
#
# c:\Users\jeyae\anaconda3\envs\bootcamp\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1787                 if not evt_handled:
#    1788                     self.dialect.do_executemany(
# -> 1789                         cursor, statement, parameters, context
#    1790                     )
#    1791             elif not parameters and context.no_parameters:
#
# c:\Users\jeyae\anaconda3\envs\bootcamp\lib\site-packages\sqlalchemy\dialects\postgresql\psycopg2.py in do_executemany(self, cursor, statement, parameters, context)
#     955                 template=executemany_values,
#     956                 fetch=bool(context.compiled.returning),
# --> 957                 **kwargs
#     958             )
#     959
#
# c:\Users\jeyae\anaconda3\envs\bootcamp\lib\site-packages\psycopg2\extras.py in execute_values(cur, sql, argslist, template, page_size, fetch)
#    1268             parts.append(b',')
#    1269         parts[-1:] = post
# -> 1270         cur.execute(b''.join(parts))
#    1271         if fetch:
#    1272             result.extend(cur.fetchall())
#
# IntegrityError: (psycopg2.errors.ForeignKeyViolation) insert or update on table "accidental_deaths" violates foreign key constraint "accidental_deaths_state_fkey"
# DETAIL:  Key (state)=(District of Columbia) is not present in table "overdoses".
#
# [SQL: INSERT INTO accidental_deaths (id, incident_id, incident_date, state, city_county, no_injured, no_killed) VALUES (%(id)s, %(incident_id)s, %(incident_date)s, %(state)s, %(city_county)s, %(no_injured)s, %(no_killed)s)]
# [parameters: ({'id': 0, 'incident_id': 2371338, 'incident_date': 'July 26, 2022', 'state': 'South Carolina', 'city_county': 'Johns Island', 'no_injured': 0, 'no_killed': 1}, {'id': 1, 'incident_id': 2370647, 'incident_date': 'July 26, 2022', 'state': 'Indiana', 'city_county': 'Muncie', 'no_injured': 0, 'no_killed': 1}, {'id': 2, 'incident_id': 2370544, 'incident_date': 'July 25, 2022', 'state': 'Washington', 'city_county': 'Ellensburg', 'no_injured': 0, 'no_killed': 1}, {'id': 3, 'incident_id': 2369189, 'incident_date': 'July 24, 2022', 'state': 'Michigan', 'city_county': 'Niles', 'no_injured': 0, 'no_killed': 1}, {'id': 4, 'incident_id': 2366931, 'incident_date': 'July 22, 2022', 'state': 'Florida', 'city_county': 'Saint Petersburg', 'no_injured': 0, 'no_killed': 1}, {'id': 5, 'incident_id': 2366254, 'incident_date': 'July 21, 2022', 'state': 'South Carolina', 'city_county': 'North Charleston', 'no_injured': 0, 'no_killed': 1}, {'id': 6, 'incident_id': 2364234, 'incident_date': 'July 19, 2022', 'state': 'Michigan', 'city_county': 'Detroit', 'no_injured': 0, 'no_killed': 1}, {'id': 7, 'incident_id': 2363850, 'incident_date': 'July 19, 2022', 'state': 'Missouri', 'city_county': 'Rogersville', 'no_injured': 0, 'no_killed': 1}  ... displaying 10 of 2000 total bound parameter sets ...  {'id': 1998, 'incident_id': 1140927, 'incident_date': 'June 13, 2018', 'state': 'Wisconsin', 'city_county': 'Madison', 'no_injured': 0, 'no_killed': 1}, {'id': 1999, 'incident_id': 1141547, 'incident_date': 'June 13, 2018', 'state': 'South Dakota', 'city_county': 'Keystone', 'no_injured': 0, 'no_killed': 1})]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)

# %%
mass_shootings = "mass_shootings_all.csv"
mass_shootings_df = pd.read_csv(mass_shootings)

columns = ["Incident ID", "Incident Date", "State", "City Or County", "# Injured", "# Killed"]
transformed_ms= mass_shootings_df[columns].copy()
transformed_ms.reset_index(inplace=True)


transformed_ms = transformed_ms.rename(columns={"index":"id",
                                                    "Incident ID": "incident_id",
                                                    "Incident Date": "incident_date",
                                                    "State": "state",
                                                    "City Or County": "city_county",
                                                    "# Injured":"no_injured",
                                                    "# Killed": "no_killed"})

transformed_ms.set_index("id", inplace=True)

transformed_ms.to_sql(name='mass_shootings', con=engine, if_exists='append', index=True)
# Out:
# ---------------------------------------------------------------------------
# ForeignKeyViolation                       Traceback (most recent call last)
# c:\Users\jeyae\anaconda3\envs\bootcamp\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1788                     self.dialect.do_executemany(
# -> 1789                         cursor, statement, parameters, context
#    1790                     )
#
# c:\Users\jeyae\anaconda3\envs\bootcamp\lib\site-packages\sqlalchemy\dialects\postgresql\psycopg2.py in do_executemany(self, cursor, statement, parameters, context)
#     956                 fetch=bool(context.compiled.returning),
# --> 957                 **kwargs
#     958             )
#
# c:\Users\jeyae\anaconda3\envs\bootcamp\lib\site-packages\psycopg2\extras.py in execute_values(cur, sql, argslist, template, page_size, fetch)
#    1269         parts[-1:] = post
# -> 1270         cur.execute(b''.join(parts))
#    1271         if fetch:
#
# ForeignKeyViolation: insert or update on table "mass_shootings" violates foreign key constraint "mass_shootings_state_fkey"
# DETAIL:  Key (state)=(District of Columbia) is not present in table "overdoses".
#
#
# The above exception was the direct cause of the following exception:
#
# IntegrityError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_436\2787973508.py in <module>
#      17 transformed_ms.set_index("id", inplace=True)
#      18
# ---> 19 transformed_ms.to_sql(name='mass_shootings', con=engine, if_exists='append', index=True)
#
# c:\Users\jeyae\anaconda3\envs\bootcamp\lib\site-packages\pandas\core\generic.py in to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2880             chunksize=chunksize,
#    2881             dtype=dtype,
# -> 2882             method=method,
#    2883         )
#    2884
#
# c:\Users\jeyae\anaconda3\envs\bootcamp\lib\site-packages\pandas\io\sql.py in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method, engine, **engine_kwargs)
#     726         method=method,
#     727         engine=engine,
# --> 728         **engine_kwargs,
#     729     )
#     730
#
# c:\Users\jeyae\anaconda3\envs\bootcamp\lib\site-packages\pandas\io\sql.py in to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method, engine, **engine_kwargs)
#    1768             chunksize=chunksize,
#    1769             method=method,
# -> 1770             **engine_kwargs,
#    1771         )
#    1772
#
# c:\Users\jeyae\anaconda3\envs\bootcamp\lib\site-packages\pandas\io\sql.py in insert_records(self, table, con, frame, name, index, schema, chunksize, method, **engine_kwargs)
#    1348                 raise ValueError("inf cannot be used with MySQL") from err
#    1349             else:
# -> 1350                 raise err
#    1351
#    1352
#
# c:\Users\jeyae\anaconda3\envs\bootcamp\lib\site-packages\pandas\io\sql.py in insert_records(self, table, con, frame, name, index, schema, chunksize, method, **engine_kwargs)
#    1338
#    1339         try:
# -> 1340             table.insert(chunksize=chunksize, method=method)
#    1341         except exc.SQLAlchemyError as err:
#    1342             # GH34431
#
# c:\Users\jeyae\anaconda3\envs\bootcamp\lib\site-packages\pandas\io\sql.py in insert(self, chunksize, method)
#     965
#     966                 chunk_iter = zip(*[arr[start_i:end_i] for arr in data_list])
# --> 967                 exec_insert(conn, keys, chunk_iter)
#     968
#     969     def _query_iterator(
#
# c:\Users\jeyae\anaconda3\envs\bootcamp\lib\site-packages\pandas\io\sql.py in _execute_insert(self, conn, keys, data_iter)
#     880         """
#     881         data = [dict(zip(keys, row)) for row in data_iter]
# --> 882         conn.execute(self.table.insert(), data)
#     883
#     884     def _execute_insert_multi(self, conn, keys: list[str], data_iter):
#
# c:\Users\jeyae\anaconda3\envs\bootcamp\lib\site-packages\sqlalchemy\engine\base.py in execute(self, statement, *multiparams, **params)
#    1293             )
#    1294         else:
# -> 1295             return meth(self, multiparams, params, _EMPTY_EXECUTION_OPTS)
#    1296
#    1297     def _execute_function(self, func, multiparams, params, execution_options):
#
# c:\Users\jeyae\anaconda3\envs\bootcamp\lib\site-packages\sqlalchemy\sql\elements.py in _execute_on_connection(self, connection, multiparams, params, execution_options, _force)
#     324         if _force or self.supports_execution:
#     325             return connection._execute_clauseelement(
# --> 326                 self, multiparams, params, execution_options
#     327             )
#     328         else:
#
# c:\Users\jeyae\anaconda3\envs\bootcamp\lib\site-packages\sqlalchemy\engine\base.py in _execute_clauseelement(self, elem, multiparams, params, execution_options)
#    1495             elem,
#    1496             extracted_params,
# -> 1497             cache_hit=cache_hit,
#    1498         )
#    1499         if has_events:
#
# c:\Users\jeyae\anaconda3\envs\bootcamp\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1850         except BaseException as e:
#    1851             self._handle_dbapi_exception(
# -> 1852                 e, statement, parameters, cursor, context
#    1853             )
#    1854
#
# c:\Users\jeyae\anaconda3\envs\bootcamp\lib\site-packages\sqlalchemy\engine\base.py in _handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    2031             elif should_wrap:
#    2032                 util.raise_(
# -> 2033                     sqlalchemy_exception, with_traceback=exc_info[2], from_=e
#    2034                 )
#    2035             else:
#
# c:\Users\jeyae\anaconda3\envs\bootcamp\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     205
#     206         try:
# --> 207             raise exception
#     208         finally:
#     209             # credit to
#
# c:\Users\jeyae\anaconda3\envs\bootcamp\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1787                 if not evt_handled:
#    1788                     self.dialect.do_executemany(
# -> 1789                         cursor, statement, parameters, context
#    1790                     )
#    1791             elif not parameters and context.no_parameters:
#
# c:\Users\jeyae\anaconda3\envs\bootcamp\lib\site-packages\sqlalchemy\dialects\postgresql\psycopg2.py in do_executemany(self, cursor, statement, parameters, context)
#     955                 template=executemany_values,
#     956                 fetch=bool(context.compiled.returning),
# --> 957                 **kwargs
#     958             )
#     959
#
# c:\Users\jeyae\anaconda3\envs\bootcamp\lib\site-packages\psycopg2\extras.py in execute_values(cur, sql, argslist, template, page_size, fetch)
#    1268             parts.append(b',')
#    1269         parts[-1:] = post
# -> 1270         cur.execute(b''.join(parts))
#    1271         if fetch:
#    1272             result.extend(cur.fetchall())
#
# IntegrityError: (psycopg2.errors.ForeignKeyViolation) insert or update on table "mass_shootings" violates foreign key constraint "mass_shootings_state_fkey"
# DETAIL:  Key (state)=(District of Columbia) is not present in table "overdoses".
#
# [SQL: INSERT INTO mass_shootings (id, incident_id, incident_date, state, city_county, no_injured, no_killed) VALUES (%(id)s, %(incident_id)s, %(incident_date)s, %(state)s, %(city_county)s, %(no_injured)s, %(no_killed)s)]
# [parameters: ({'id': 0, 'incident_id': 2371416, 'incident_date': 'July 27, 2022', 'state': 'Louisiana', 'city_county': 'Hahnville', 'no_injured': 3, 'no_killed': 1}, {'id': 1, 'incident_id': 2370760, 'incident_date': 'July 27, 2022', 'state': 'Georgia', 'city_county': 'Macon', 'no_injured': 2, 'no_killed': 2}, {'id': 2, 'incident_id': 2369720, 'incident_date': 'July 25, 2022', 'state': 'Louisiana', 'city_county': 'New Orleans', 'no_injured': 4, 'no_killed': 0}, {'id': 3, 'incident_id': 2368575, 'incident_date': 'July 24, 2022', 'state': 'California', 'city_county': 'San Pedro', 'no_injured': 6, 'no_killed': 2}, {'id': 4, 'incident_id': 2368110, 'incident_date': 'July 24, 2022', 'state': 'South Carolina', 'city_county': 'Bennettsville', 'no_injured': 3, 'no_killed': 1}, {'id': 5, 'incident_id': 2368029, 'incident_date': 'July 24, 2022', 'state': 'Georgia', 'city_county': 'Atlanta', 'no_injured': 8, 'no_killed': 0}, {'id': 6, 'incident_id': 2368308, 'incident_date': 'July 24, 2022', 'state': 'Texas', 'city_county': 'Fort Worth', 'no_injured': 3, 'no_killed': 1}, {'id': 7, 'incident_id': 2367664, 'incident_date': 'July 23, 2022', 'state': 'Texas', 'city_county': 'El Paso', 'no_injured': 4, 'no_killed': 0}  ... displaying 10 of 2000 total bound parameter sets ...  {'id': 1998, 'incident_id': 1381273, 'incident_date': 'April 27, 2019', 'state': 'California', 'city_county': 'Poway', 'no_injured': 3, 'no_killed': 1}, {'id': 1999, 'incident_id': 1381734, 'incident_date': 'April 27, 2019', 'state': 'California', 'city_county': 'Los Angeles', 'no_injured': 6, 'no_killed': 0})]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)

# %%
accidental_injuries = "accidental_injuries.csv"
accidental_injuries_df = pd.read_csv(accidental_injuries)


columns = ["Incident ID", "Incident Date", "State", "City Or County", "# Injured", "# Killed"]
transformed_ai= accidental_injuries_df[columns].copy()
transformed_ai.reset_index(inplace=True)


transformed_ai = transformed_ai.rename(columns={"index":"id",
                                                    "Incident ID": "incident_id",
                                                    "Incident Date": "incident_date",
                                                    "State": "state",
                                                    "City Or County": "city_county",
                                                    "# Injured":"no_injured",
                                                    "# Killed": "no_killed"})

transformed_ai.set_index("id", inplace=True)

transformed_ai.to_sql(name='accidental_injuries', con=engine, if_exists='append', index=True)
# Out:
# ---------------------------------------------------------------------------
# ForeignKeyViolation                       Traceback (most recent call last)
# c:\Users\jeyae\anaconda3\envs\bootcamp\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1788                     self.dialect.do_executemany(
# -> 1789                         cursor, statement, parameters, context
#    1790                     )
#
# c:\Users\jeyae\anaconda3\envs\bootcamp\lib\site-packages\sqlalchemy\dialects\postgresql\psycopg2.py in do_executemany(self, cursor, statement, parameters, context)
#     956                 fetch=bool(context.compiled.returning),
# --> 957                 **kwargs
#     958             )
#
# c:\Users\jeyae\anaconda3\envs\bootcamp\lib\site-packages\psycopg2\extras.py in execute_values(cur, sql, argslist, template, page_size, fetch)
#    1269         parts[-1:] = post
# -> 1270         cur.execute(b''.join(parts))
#    1271         if fetch:
#
# ForeignKeyViolation: insert or update on table "accidental_injuries" violates foreign key constraint "accidental_injuries_state_fkey"
# DETAIL:  Key (state)=(District of Columbia) is not present in table "overdoses".
#
#
# The above exception was the direct cause of the following exception:
#
# IntegrityError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_436\1655340876.py in <module>
#      18 transformed_ai.set_index("id", inplace=True)
#      19
# ---> 20 transformed_ai.to_sql(name='accidental_injuries', con=engine, if_exists='append', index=True)
#
# c:\Users\jeyae\anaconda3\envs\bootcamp\lib\site-packages\pandas\core\generic.py in to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2880             chunksize=chunksize,
#    2881             dtype=dtype,
# -> 2882             method=method,
#    2883         )
#    2884
#
# c:\Users\jeyae\anaconda3\envs\bootcamp\lib\site-packages\pandas\io\sql.py in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method, engine, **engine_kwargs)
#     726         method=method,
#     727         engine=engine,
# --> 728         **engine_kwargs,
#     729     )
#     730
#
# c:\Users\jeyae\anaconda3\envs\bootcamp\lib\site-packages\pandas\io\sql.py in to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method, engine, **engine_kwargs)
#    1768             chunksize=chunksize,
#    1769             method=method,
# -> 1770             **engine_kwargs,
#    1771         )
#    1772
#
# c:\Users\jeyae\anaconda3\envs\bootcamp\lib\site-packages\pandas\io\sql.py in insert_records(self, table, con, frame, name, index, schema, chunksize, method, **engine_kwargs)
#    1348                 raise ValueError("inf cannot be used with MySQL") from err
#    1349             else:
# -> 1350                 raise err
#    1351
#    1352
#
# c:\Users\jeyae\anaconda3\envs\bootcamp\lib\site-packages\pandas\io\sql.py in insert_records(self, table, con, frame, name, index, schema, chunksize, method, **engine_kwargs)
#    1338
#    1339         try:
# -> 1340             table.insert(chunksize=chunksize, method=method)
#    1341         except exc.SQLAlchemyError as err:
#    1342             # GH34431
#
# c:\Users\jeyae\anaconda3\envs\bootcamp\lib\site-packages\pandas\io\sql.py in insert(self, chunksize, method)
#     965
#     966                 chunk_iter = zip(*[arr[start_i:end_i] for arr in data_list])
# --> 967                 exec_insert(conn, keys, chunk_iter)
#     968
#     969     def _query_iterator(
#
# c:\Users\jeyae\anaconda3\envs\bootcamp\lib\site-packages\pandas\io\sql.py in _execute_insert(self, conn, keys, data_iter)
#     880         """
#     881         data = [dict(zip(keys, row)) for row in data_iter]
# --> 882         conn.execute(self.table.insert(), data)
#     883
#     884     def _execute_insert_multi(self, conn, keys: list[str], data_iter):
#
# c:\Users\jeyae\anaconda3\envs\bootcamp\lib\site-packages\sqlalchemy\engine\base.py in execute(self, statement, *multiparams, **params)
#    1293             )
#    1294         else:
# -> 1295             return meth(self, multiparams, params, _EMPTY_EXECUTION_OPTS)
#    1296
#    1297     def _execute_function(self, func, multiparams, params, execution_options):
#
# c:\Users\jeyae\anaconda3\envs\bootcamp\lib\site-packages\sqlalchemy\sql\elements.py in _execute_on_connection(self, connection, multiparams, params, execution_options, _force)
#     324         if _force or self.supports_execution:
#     325             return connection._execute_clauseelement(
# --> 326                 self, multiparams, params, execution_options
#     327             )
#     328         else:
#
# c:\Users\jeyae\anaconda3\envs\bootcamp\lib\site-packages\sqlalchemy\engine\base.py in _execute_clauseelement(self, elem, multiparams, params, execution_options)
#    1495             elem,
#    1496             extracted_params,
# -> 1497             cache_hit=cache_hit,
#    1498         )
#    1499         if has_events:
#
# c:\Users\jeyae\anaconda3\envs\bootcamp\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1850         except BaseException as e:
#    1851             self._handle_dbapi_exception(
# -> 1852                 e, statement, parameters, cursor, context
#    1853             )
#    1854
#
# c:\Users\jeyae\anaconda3\envs\bootcamp\lib\site-packages\sqlalchemy\engine\base.py in _handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    2031             elif should_wrap:
#    2032                 util.raise_(
# -> 2033                     sqlalchemy_exception, with_traceback=exc_info[2], from_=e
#    2034                 )
#    2035             else:
#
# c:\Users\jeyae\anaconda3\envs\bootcamp\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     205
#     206         try:
# --> 207             raise exception
#     208         finally:
#     209             # credit to
#
# c:\Users\jeyae\anaconda3\envs\bootcamp\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1787                 if not evt_handled:
#    1788                     self.dialect.do_executemany(
# -> 1789                         cursor, statement, parameters, context
#    1790                     )
#    1791             elif not parameters and context.no_parameters:
#
# c:\Users\jeyae\anaconda3\envs\bootcamp\lib\site-packages\sqlalchemy\dialects\postgresql\psycopg2.py in do_executemany(self, cursor, statement, parameters, context)
#     955                 template=executemany_values,
#     956                 fetch=bool(context.compiled.returning),
# --> 957                 **kwargs
#     958             )
#     959
#
# c:\Users\jeyae\anaconda3\envs\bootcamp\lib\site-packages\psycopg2\extras.py in execute_values(cur, sql, argslist, template, page_size, fetch)
#    1268             parts.append(b',')
#    1269         parts[-1:] = post
# -> 1270         cur.execute(b''.join(parts))
#    1271         if fetch:
#    1272             result.extend(cur.fetchall())
#
# IntegrityError: (psycopg2.errors.ForeignKeyViolation) insert or update on table "accidental_injuries" violates foreign key constraint "accidental_injuries_state_fkey"
# DETAIL:  Key (state)=(District of Columbia) is not present in table "overdoses".
#
# [SQL: INSERT INTO accidental_injuries (id, incident_id, incident_date, state, city_county, no_injured, no_killed) VALUES (%(id)s, %(incident_id)s, %(incident_date)s, %(state)s, %(city_county)s, %(no_injured)s, %(no_killed)s)]
# [parameters: ({'id': 0, 'incident_id': 2371477, 'incident_date': 'July 27, 2022', 'state': 'Pennsylvania', 'city_county': 'Philadelphia', 'no_injured': 1, 'no_killed': 0}, {'id': 1, 'incident_id': 2370618, 'incident_date': 'July 26, 2022', 'state': 'Michigan', 'city_county': 'Detroit', 'no_injured': 1, 'no_killed': 0}, {'id': 2, 'incident_id': 2370812, 'incident_date': 'July 26, 2022', 'state': 'Illinois', 'city_county': 'Chicago', 'no_injured': 1, 'no_killed': 0}, {'id': 3, 'incident_id': 2369373, 'incident_date': 'July 25, 2022', 'state': 'Michigan', 'city_county': 'Detroit', 'no_injured': 1, 'no_killed': 0}, {'id': 4, 'incident_id': 2369851, 'incident_date': 'July 25, 2022', 'state': 'Louisiana', 'city_county': 'Port Allen', 'no_injured': 1, 'no_killed': 0}, {'id': 5, 'incident_id': 2371515, 'incident_date': 'July 24, 2022', 'state': 'New York', 'city_county': 'New Hampton', 'no_injured': 1, 'no_killed': 0}, {'id': 6, 'incident_id': 2369295, 'incident_date': 'July 24, 2022', 'state': 'Ohio', 'city_county': 'Columbus', 'no_injured': 3, 'no_killed': 0}, {'id': 7, 'incident_id': 2369260, 'incident_date': 'July 24, 2022', 'state': 'Ohio', 'city_county': 'Cleveland', 'no_injured': 1, 'no_killed': 0}  ... displaying 10 of 2000 total bound parameter sets ...  {'id': 1998, 'incident_id': 1900085, 'incident_date': 'January 9, 2021', 'state': 'Nebraska', 'city_county': 'Alliance', 'no_injured': 1, 'no_killed': 0}, {'id': 1999, 'incident_id': 1898916, 'incident_date': 'January 9, 2021', 'state': 'New York', 'city_county': 'New York (Manhattan)', 'no_injured': 1, 'no_killed': 0})]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
